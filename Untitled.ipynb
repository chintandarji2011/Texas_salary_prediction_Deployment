# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\chint\\Downloads\\Datamites\\Internship Projects\\Texas_Employee_Salary_Prediction\\Final_Project_files'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'app.py',
#  'Final_Texas_Salary_Prediction.ipynb',
#  'salary.csv',
#  'templates',
#  'texas_salary_prediction.pkl',
#  'Untitled.ipynb']

# %%
# !python app.py
# Out:
# ^C

# %%
import os

print(os.path.exists("class_title_encoder.pkl"))
# Out:
# True

# %% [raw]
# -> For Anaconda prompt
# cd "C:\Users\chint\Downloads\Datamites\Internship Projects\Texas_Employee_Salary_Prediction\Final_Project_files"
#
# python app.py

# %% [raw]
# open in web page
# http://127.0.0.1:5000/

# %% [raw]
# - create requiredment.txt and put below:
#
# Flask
# pandas
# numpy
# scikit-learn
# joblib
# gunicorn
#
# - in Anaconda prompt-->  pip install -r requirements.txt
# - python app.py
# - on Web page: http://127.0.0.1:5000/

# %%
with open(".gitignore", "r") as f:
    print(f.read())
# Out:
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
# .venv/
# venv/
# env/
# salary.csv

# %%
with open(".gitignore", "w") as f:
    f.write("""__pycache__/
*.pyc
.ipynb_checkpoints/
.venv/
venv/
env/
salary.csv
""")

# %%
with open(".gitignore", "r") as f:
    print(f.read())
# Out:
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
# .venv/
# venv/
# env/
# salary.csv
